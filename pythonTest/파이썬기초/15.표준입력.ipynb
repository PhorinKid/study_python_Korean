# %%
print('hello') # 표준출력 (모니터)

# %% [markdown]
# #### 표준입력(키보드)

# %%
a = input('입력 : ')
print(a)
print(type(a))
# Out:
# 4
# <class 'str'>

# %%
pi = 3.14
r = float(input('반지름 : '))
area = r**2 * pi
print(area)
# Out:
# 78.5
