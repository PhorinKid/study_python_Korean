# %% [markdown]
# 대입연산자 (문법 : 산술연산자=)
# ```text
# - **=
# - *=
# - /=
# - %=
# - //=
# - +=
# - -=

# %%
a = 5

a += 2 # a = a+2
print(a)
# Out:
# 7

# %%
b = 5

b **= 2 # b = b**2
print(b)
# Out:
# 25

# %%
c = 5

c  /=2 # c = c/2
print(c)
# Out:
# 2.5
