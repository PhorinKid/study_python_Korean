# %%
# mymath 폴더 아래에 있는 danwi.py 함수 사용

import mymath.dnawi

rst = mymath.dnawi.cmInch(10)
print(rst)
rst = mymath.dnawi.mMile(100)
print(rst)
# Out:
# 3.937
# 0.0621

# %%
import mymath.dnawi as d
import mymath.circle as c

rst = d.cmInch(10)
print(rst)
rst = d.mMile(100)
print(rst)

rst = c.area(5)
print(rst)
# Out:
# 3.937
# 0.0621
# 78.5

# %%
from mymath.dnawi import cmInch

rst = cmInch(10)
print(rst)
# Out:
# 3.937

# %% [markdown]
# #### 라이브러리 종류
# 1. 내장함수 (print, input, int, list, ...) : import 없이 사용
# 2. 표준함수 (파이썬 제공) : import 후 사용
# 파이썬경로\lib
# import sys
# import os
# import math
# ...
# 3. 써드파티 라이브러리 (다른 사람이 만든 라이브러리)

# %%
import sys

sys.path # python path (import 라이브러리명을 인식할 수 있는 경로)
# Out:
# ['c:\\Python310\\python310.zip',
#  'c:\\Python310\\DLLs',
#  'c:\\Python310\\lib',
#  'c:\\Python310',
#  '',
#  'C:\\Users\\Dell5371\\AppData\\Roaming\\Python\\Python310\\site-packages',
#  'c:\\Python310\\lib\\site-packages']
