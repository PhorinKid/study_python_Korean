# %% [markdown]
# 삼항연산자
#
# (True시 출력 값 if 논리연산 else False시 출력 값)

# %%
a = 5
rst = 100 if a>0 else 200
print(rst)
# Out:
# 100

# %%
# 점수가 70 이상 - 합격 / 미만 - 불합격
# 점수가 92 점인 경우 합격 여부

score = 92
rst = '합격' if score>=70 else '불합격'
print(rst)
# Out:
# 합격
